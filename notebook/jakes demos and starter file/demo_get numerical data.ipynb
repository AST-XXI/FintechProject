# %%
import pandas as pd
ticker='ZRXUSD'
screener="CRYPTO"
exchange="COINBASE"
ta_interval ='Interval.INTERVAL_1_DAY'
from tradingview_ta import TA_Handler, Interval, Exchange
trading_api = TA_Handler(
    symbol=ticker,
    screener=screener,
    exchange=exchange,
    interval=Interval.INTERVAL_1_DAY
)

# %%
#Get all indicator. 
tradingapi_indicator_data = (trading_api.get_analysis().indicators)
tradingapi_indicator_data
# Out:
# {'Recommend.Other': -0.09090909,
#  'Recommend.All': 0.08787879,
#  'Recommend.MA': 0.26666667,
#  'RSI': 50.68412981,
#  'RSI[1]': 49.97204909,
#  'Stoch.K': 38.87576528,
#  'Stoch.D': 37.01524202,
#  'Stoch.K[1]': 37.82098472,
#  'Stoch.D[1]': 35.20822268,
#  'CCI20': -26.9644773,
#  'CCI20[1]': -34.4693503,
#  'ADX': 22.74258665,
#  'ADX+DI': 17.35186372,
#  'ADX-DI': 19.88822368,
#  'ADX+DI[1]': 16.83288046,
#  'ADX-DI[1]': 20.66513218,
#  'AO': -0.0452065,
#  'AO[1]': -0.04566746,
#  'Mom': -0.238596,
#  'Mom[1]': -0.181499,
#  'MACD.macd': 0.00543292,
#  'MACD.signal': 0.02185699,
#  'Rec.Stoch.RSI': 0,
#  'Stoch.RSI.K': 15.32722886,
#  'Rec.WR': 0,
#  'W.R': -56.12460746,
#  'Rec.BBPower': 1,
#  'BBPower': -0.03333656,
#  'Rec.UO': 0,
#  'UO': 64.55450857,
#  'close': 1.073838,
#  'EMA5': 1.05781123,
#  'SMA5': 1.0474132,
#  'EMA10': 1.06872194,
#  'SMA10': 1.062573,
#  'EMA20': 1.07526074,
#  'SMA20': 1.10109125,
#  'EMA30': 1.05952571,
#  'SMA30': 1.0891704,
#  'EMA50': 1.0219114,
#  'SMA50': 1.01623296,
#  'EMA100': 1.01007657,
#  'SMA100': 0.87482302,
#  'EMA200': 1.01697427,
#  'SMA200': 1.20522076,
#  'Rec.Ichimoku': 0,
#  'Ichimoku.BLine': 1.100128,
#  'Rec.VWMA': -1,
#  'VWMA': 1.094465,
#  'Rec.HullMA9': 1,
#  'HullMA9': 1.05443017,
#  'Pivot.M.Classic.S3': 0.13435667,
#  'Pivot.M.Classic.S2': 0.56830767,
#  'Pivot.M.Classic.S1': 0.81525333,
#  'Pivot.M.Classic.Middle': 1.00225867,
#  'Pivot.M.Classic.R1': 1.24920433,
#  'Pivot.M.Classic.R2': 1.43620967,
#  'Pivot.M.Classic.R3': 1.87016067,
#  'Pivot.M.Fibonacci.S3': 0.56830767,
#  'Pivot.M.Fibonacci.S2': 0.73407695,
#  'Pivot.M.Fibonacci.S1': 0.83648938,
#  'Pivot.M.Fibonacci.Middle': 1.00225867,
#  'Pivot.M.Fibonacci.R1': 1.16802795,
#  'Pivot.M.Fibonacci.R2': 1.27044038,
#  'Pivot.M.Fibonacci.R3': 1.43620967,
#  'Pivot.M.Camarilla.S3': 0.94286247,
#  'Pivot.M.Camarilla.S2': 0.98264132,
#  'Pivot.M.Camarilla.S1': 1.02242016,
#  'Pivot.M.Camarilla.Middle': 1.00225867,
#  'Pivot.M.Camarilla.R1': 1.10197784,
#  'Pivot.M.Camarilla.R2': 1.14175668,
#  'Pivot.M.Camarilla.R3': 1.18153552,
#  'Pivot.M.Woodie.S3': 0.4123255,
#  'Pivot.M.Woodie.S2': 0.58381925,
#  'Pivot.M.Woodie.S1': 0.8462765,
#  'Pivot.M.Woodie.Middle': 1.01777025,
#  'Pivot.M.Woodie.R1': 1.2802275,
#  'Pivot.M.Woodie.R2': 1.45172125,
#  'Pivot.M.Woodie.R3': 1.7141785,
#  'Pivot.M.Demark.S1': 0.908756,
#  'Pivot.M.Demark.Middle': 1.04901,
#  'Pivot.M.Demark.R1': 1.342707,
#  'open': 1.064419,
#  'P.SAR': 1.20806233,
#  'BB.lower': 0.92433632,
#  'BB.upper': 1.27784618,
#  'AO[2]': -0.04382055,
#  'volume': 4133771.1502,
#  'change': 0.88754978,
#  'low': 1.03007,
#  'high': 1.084807}
