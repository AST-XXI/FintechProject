# %%
#The name of this project is 'Cryptara' and the objective of this script is to build a Robo-advisor
name = input("Welcome Crypto Investor, what is your name?")
# Out:
# Welcome Crypto Investor, what is your name? Elon

# %%
#Introduction. Have user input their desired upload option. Options include importing a csv or inputting individual tickers.
if name == None:
    print('I respect your privacy, you dont mind if I call you Karen, right')
    name = "Karen"
if name != "" or name == None:
    # Store user's cash investment.
    print(f"Hello {name}, my name is Cryptara. I make your savings go to good use in the Crypto market..")
    print('')
    data_source=input("Would you like to import a csv file or input your tickers manually? Type: 'import' OR 'input'")
    print(f"{data_source} option has been selected..")
    print(f"")
    investment=input("how much cash would you like to invest?")
    investment = float(investment)
    print('')
    print(f'Once I have your list, this process starts automatically..')
    print(f'I use data from the TradingView API and filter your list, then I apply a built-in technical analysis function to determine which cryptos are good picks at this point in time')
    print(f"Then, I run hundreds of simulations to determine optimal weights for each crypto selection")
    print(f"From there, I will scan multiple exchanges to determine where you could get the most volume for the dollar at that particular time '(based on cross-exchange rates)'")
    print(f"Lastly, I will present to you an interactive Dashboard along with my future projections..")
# Out:
# Hello Elon, my name is Cryptara. I make your savings go to good use in the Crypto market..
# Would you like to import a csv file or input your tickers manually? Type: 'import' OR 'input' import
# import option has been selected..
# how much cash would you like to invest? 100000000
# Once I have your list, this process starts automatically..
# I use data from the TradingView API and filter your list, then I apply a built-in technical analysis function to determine which cryptos are good picks at this point in time
# Then, I run hundreds of simulations to determine optimal weights for each crypto selection
# From there, I will scan multiple exchanges to determine where you could get the most volume for the dollar at that particular time '(based on cross-exchange rates)'
# Lastly, I will present to you an interactive Dashboard along with my future projections..

# %%
#User input validation
if data_source == 'import':
    from pathlib import Path
    ticker_data = Path("data_files/crypto_tickers1.csv")
    print(f'Thanks for using our csv file import option! Let me look through your list and see if I can validate the data..')
if data_source == 'input':
    ticker_1=input("Tell me the first ticker")
    ticker_2=input("Tell me the second ticker")
    ticker_3=input("Tell me the third ticker")
    ticker_4=input("Tell me the fourth ticker")
    ticker_5=input("Tell me the fifth ticker")
    ticker_6=input("Tell me the sixth ticker")
    ticker_7=input("Tell me the seventh ticker")
    ticker_8=input("Tell me the eigth ticker")
    ticker_9=input("Tell me the ninth ticker")
    print("Please upgrade to our Premium version of Cryptana to input more than nine tickers.")
    ticker_data = ([ticker_1,ticker_2,ticker_3,ticker_4,ticker_5,ticker_6,ticker_7,ticker_8,ticker_7,ticker_8,ticker_9])
    print(f'Got it. Give me a minute to make sure these tickers are valid')
if data_source != 'import':
    if data_source != 'input':
        data_source = input('Please try again..')
# Out:
# Thanks for using our csv file import option! Let me look through your list and see if I can validate the data..

# %%
#Import libraries and dependencies
print(f'Lets get warmed up..')
from dotenv import load_dotenv
from itertools import product
import datetime
import os
import random
import logging
import pandas as pd
import numpy as np
from pathlib import Path
# %matplotlib inline
# Out:
# Lets get warmed up..

# %%
#Create TradingView variable and activate env variables
print(f'Trading View is my trusted partner, together we will see where your money should go')
from tvDatafeed import TvDatafeed,Interval
load_dotenv()
tradev_id = os.getenv("username")
tradev_secret_key = os.getenv("password")
# Out:
# Trading View is my trusted partner, together we will see where your money should go

# %%
#Log into TradingView
logging.basicConfig(level=logging.DEBUG)
tv = TvDatafeed(tradev_id, tradev_secret_key, chromedriver_path=None)
print('TradingView Authentication is successfull')
# Out:
# DEBUG:tvDatafeed.main:auth loaded
# TradingView Authentication is successfull

# %%
from pathlib import Path
ticker_data = Path("data_files/crypto_tickers1.csv")
ticker= pd.read_csv(ticker_data, header=None)
ticker_df = pd.DataFrame(ticker)
my_crypto_list = ticker_df[0].tolist()
screener="CRYPTO"
exchange="BINANCE"
df_daily = pd.DataFrame()
print(f"Nice work! No issues have been identified with your list, let me look into these and get back to you shortly...")
# Out:
# Nice work! No issues have been identified with your list, let me look into these and get back to you shortly...

# %%
#Get historical pricing information for total population
print(f'Extracting price history..')
for ticker in my_crypto_list:
    data = tv.get_hist(
        symbol=ticker,
        exchange=exchange,
        interval=Interval.in_daily,n_bars=500)
    df_daily = df_daily.append(data)
print(f'finished extracting historical prices..')
# Out:
# DEBUG:root:creating websocket connection
# Extracting price history..
# DEBUG:tvDatafeed.main:getting data for BINANCE:BTCUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ETHUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:DOGEUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:LTCUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:VGXETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:VGXBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:MBOXBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TRIBEUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TRIBEBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TRIBEBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:MITHBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BTCDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:VTHOBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:1INCHDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:HARDBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:MITHUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:EOSDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BNBDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTRUB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:GLMETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ETHDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BCHDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:PHABTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:CELOUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:CREAMBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ELFETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BURGERBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDBRL...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTBRL...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:COVERBUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:MATICBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:AAVEDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:GXSBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:FUNBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TRXXRP...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:LINKDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:GLMBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:MDABTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:YFIDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:FILDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:SXPDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDRUB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:SWRVBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TRXDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ADADOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:PAXGUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:PAXGBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:SYSBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTIDRT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ADABTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:DOTDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:COVERETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TROYUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:MITHUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTNGN...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:OMGBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDBIDR...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTBIDR...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TROYBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TUSDUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:XRPDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:CELOBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:MITHBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TRIBEBUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TRIBEUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ADXBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:PAXGBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:RIFBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:WINBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:PERLBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:LTCBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BATETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:JUVBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:AKROUSDT_PREMIUM...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:COTIBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ATMBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BTCDOMUSDTPERP...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:DASHETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:PSGBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTBVND...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:DASHBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:GXSETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:POLSBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ACMBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:FETBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:SYSBUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ADAETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:SYSUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:OMGETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ELFBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDBVND...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:WRXBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDUAH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:SUSHIDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ADABNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:LPTBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:WBTCETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:CLVBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TORNBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:MINABNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:SOLBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:SOLBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TRXBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:NMRBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:QLCETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ADXETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:FETBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTUAH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:FUNETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:UNIDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:WRXBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:PAXGUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:WINTRX...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:LPTBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTDAI...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:LTCDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ASRBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:CLVBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTTRY...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:DEXEETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:OXTBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:GHSTETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:RENBTCBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:CELOUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDTRY...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:XLMDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:DASHBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:PAXGUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:PERLBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:QNTBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:FIOBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDDAI...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:AVABNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:FTTBUSD_PREMIUM...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:TROYBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:ELFBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:OMGETH...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:SYSBUSD...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:PAXGBNB...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:GLMETH...
# finished extracting historical prices..

# %%
#Grab indicator recommendations from Trading View API
print(f'Risk protocol: Filtering by analyst recommendations')
from tradingview_ta import TA_Handler, Interval, Exchange
staging_df = pd.DataFrame()
ticker_df_daily = pd.DataFrame()
for ticker in my_crypto_list:
    try:
        data = (TA_Handler(symbol=ticker,screener=screener,
                           exchange=exchange,interval=Interval.INTERVAL_1_DAY ).get_analysis().summary)
        symbol = ticker
        staging_df = list(data.values())
        final_df = (pd.DataFrame((data), index={ticker}))
        ticker_df_daily = ticker_df_daily.append(final_df)
    except:
        pass
print(f'finished extracting analyst recommendations..')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# Risk protocol: Filtering by analyst recommendations
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# finished extracting analyst recommendations..

# %%
#Filter imported list by analyst recommendations
print(f'We checked what the top analysts are saying about each crypto in your list')
print(f'To reduce program speed, Cryptara will only analyze cryptos that meet a BUY or NEUTRAL classification')
initial_drop = ticker_df_daily.loc[ticker_df_daily['RECOMMENDATION']=='SELL']
initial_pass_prime = ticker_df_daily.loc[ticker_df_daily['RECOMMENDATION']=='BUY']
initial_pass_subprime = ticker_df_daily.loc[ticker_df_daily['RECOMMENDATION']=='NEUTRAL']

#initial_drop = initial_indicator['RECOMMENDATION'].str.contains('SELL')
buy_count = initial_pass_prime['RECOMMENDATION'].count() + initial_pass_subprime['RECOMMENDATION'].count()
sell_count = initial_drop['RECOMMENDATION'].count()
print('Here are the initial findings:')
print('')
print(f'It is not a good time to invest in {sell_count} of the cryptos from your list')
print(f'These {sell_count} cryptos are not in a buying position')
print(initial_drop['RECOMMENDATION'])
print(f'These {sell_count} cryptos have been dropped from consideration..')
print('')
print('')
print(f'Moving on, our initial inidicator data suggest {buy_count} cryptos from your list should be considered for further analysis:')
print('Here they are:')
print('Our Prime candidates that are in buy positions are:')
print(initial_pass_prime['RECOMMENDATION'])
print('')
print('And these are neutral for now, we can resverve for later if we need additional cryptos for analysis')
print(initial_pass_subprime['RECOMMENDATION'])
# Out:
# We checked what the top analysts are saying about each crypto in your list
# To reduce program speed, Cryptara will only analyze cryptos that meet a BUY or NEUTRAL classification
# Here are the initial findings:
#
# It is not a good time to invest in 55 of the cryptos from your list
# These 55 cryptos are not in a buying position
# BTCUSD              SELL
# DOGEUSD             SELL
# LTCUSD              SELL
# TRIBEUSD            SELL
# TRIBEBTC            SELL
# MITHBNB             SELL
# MITHUSD             SELL
# USDTRUB             SELL
# GLMETH              SELL
# BURGERBNB           SELL
# COVERBUSD           SELL
# GXSBTC              SELL
# FUNBTC              SELL
# LINKDOWNUSDT        SELL
# MDABTC              SELL
# FILDOWNUSDT         SELL
# SXPDOWNUSDT         SELL
# BUSDRUB             SELL
# ADADOWNUSDT         SELL
# PAXGUSDT            SELL
# USDTIDRT            SELL
# COVERETH            SELL
# MITHUSDT            SELL
# BUSDBIDR            SELL
# USDTBIDR            SELL
# XRPDOWNUSDT         SELL
# MITHBTC             SELL
# ADXBTC              SELL
# RIFBTC              SELL
# WINBNB              SELL
# LTCBNB              SELL
# BATETH              SELL
# JUVBTC              SELL
# AKROUSDT_PREMIUM    SELL
# ATMBTC              SELL
# PSGBTC              SELL
# DASHBNB             SELL
# BUSDBVND            SELL
# WRXBTC              SELL
# SUSHIDOWNUSDT       SELL
# QLCETH              SELL
# ADXETH              SELL
# FUNETH              SELL
# WRXBNB              SELL
# PAXGUSD             SELL
# WINTRX              SELL
# CLVBTC              SELL
# BUSDUSDT            SELL
# OXTBTC              SELL
# GHSTETH             SELL
# DASHBTC             SELL
# PAXGUSD             SELL
# AVABNB              SELL
# FTTBUSD_PREMIUM     SELL
# GLMETH              SELL
# Name: RECOMMENDATION, dtype: object
# These 55 cryptos have been dropped from consideration..
#
#
# Moving on, our initial inidicator data suggest 74 cryptos from your list should be considered for further analysis:
# Here they are:
# Our Prime candidates that are in buy positions are:
# VGXETH            BUY
# MBOXBNB           BUY
# TRIBEBNB          BUY
# VTHOBNB           BUY
# HARDBNB           BUY
# ETHDOWNUSDT       BUY
# PHABTC            BUY
# CELOUSD           BUY
# ELFETH            BUY
# BUSDBRL           BUY
# USDTBRL           BUY
# TRXXRP            BUY
# SWRVBNB           BUY
# TRXDOWNUSDT       BUY
# SYSBTC            BUY
# ADABTC            BUY
# TROYUSDT          BUY
# OMGBTC            BUY
# TROYBNB           BUY
# CELOBTC           BUY
# PERLBNB           BUY
# BTCDOMUSDTPERP    BUY
# ACMBTC            BUY
# ADAETH            BUY
# OMGETH            BUY
# ELFBTC            BUY
# ADABNB            BUY
# LPTBTC            BUY
# TORNBNB           BUY
# MINABNB           BUY
# SOLBTC            BUY
# SOLBNB            BUY
# TRXBNB            BUY
# NMRBNB            BUY
# FETBNB            BUY
# UNIDOWNUSDT       BUY
# LPTBNB            BUY
# LTCDOWNUSDT       BUY
# ASRBTC            BUY
# USDTTRY           BUY
# CELOUSDT          BUY
# BUSDTRY           BUY
# XLMDOWNUSDT       BUY
# PERLBTC           BUY
# QNTBNB            BUY
# BUSDDAI           BUY
# TROYBNB           BUY
# ELFBTC            BUY
# OMGETH            BUY
# Name: RECOMMENDATION, dtype: object
#
# And these are neutral for now, we can resverve for later if we need additional cryptos for analysis
# ETHUSD           NEUTRAL
# VGXBTC           NEUTRAL
# BTCDOWNUSDT      NEUTRAL
# 1INCHDOWNUSDT    NEUTRAL
# EOSDOWNUSDT      NEUTRAL
# BNBDOWNUSDT      NEUTRAL
# BCHDOWNUSDT      NEUTRAL
# CREAMBNB         NEUTRAL
# MATICBNB         NEUTRAL
# AAVEDOWNUSDT     NEUTRAL
# GLMBTC           NEUTRAL
# YFIDOWNUSDT      NEUTRAL
# PAXGBTC          NEUTRAL
# USDTNGN          NEUTRAL
# TUSDUSDT         NEUTRAL
# PAXGBNB          NEUTRAL
# GXSETH           NEUTRAL
# POLSBNB          NEUTRAL
# FETBTC           NEUTRAL
# SYSBUSD          NEUTRAL
# SYSUSD           NEUTRAL
# WBTCETH          NEUTRAL
# DEXEETH          NEUTRAL
# SYSBUSD          NEUTRAL
# PAXGBNB          NEUTRAL
# Name: RECOMMENDATION, dtype: object

# %%
#Extract index values for the tickers that are prime and subprime and format data for further analysis. 
print(f'Nice work, {name}, you found {buy_count} cryptos that might be good investments this week!')
initial_pass_prime.reset_index(inplace=True)
initial_pass_prime = initial_pass_prime['index']
initial_pass_subprime.reset_index(inplace=True)
initial_pass_subprime = initial_pass_subprime['index']
staging_df = pd.DataFrame()
staging_df1 = pd.DataFrame()
prime_df = pd.DataFrame()
subprime_df = pd.DataFrame()
print(f'Lets see what Cryptara thinks about these cryptos..')
print(f'')
# Out:
# Nice work, Elon, you found 74 cryptos that might be good investments this week!
# Lets see what Cryptara thinks about these cryptos..

# %%
#Run a for loop through prime and subprime cryptos and pull in all oscilattor data for technical analysis
#Prime cryptos
print(f'Extracting oscillator data from TradingView for built in technical analysis test...')
for ticker in initial_pass_prime:
    try:
        data = (TA_Handler(symbol=ticker,screener=screener,
                           exchange=exchange,interval=Interval.INTERVAL_1_DAY ).get_analysis().indicators)
        symbol = ticker
        staging_df = list(data.values())
        final_df = (pd.DataFrame((data), index={ticker}))
        prime_df = prime_df.append(final_df)
    except:
        pass

#Sub-prime cryptos
for ticker in initial_pass_subprime:
    try:
        data = (TA_Handler(symbol=ticker,screener=screener,
                           exchange=exchange,interval=Interval.INTERVAL_1_DAY ).get_analysis().indicators)
        symbol = ticker
        staging_df1 = list(data.values())
        final_df = (pd.DataFrame((data), index={ticker}))
        subprime_df = subprime_df.append(final_df)
    except:
        pass
print('Extracted oscillator data, initializing technical analysis test on key trend indicators..')
prime_df.head(3)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# Extracting oscillator data from TradingView for built in technical analysis test...
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): scanner.tradingview.com:443
# DEBUG:urllib3.connectionpool:https://scanner.tradingview.com:443 "POST /crypto/scan HTTP/1.1" 200 None
# Extracted oscillator data, initializing technical analysis test on key trend indicators..
#           Recommend.Other  Recommend.All  Recommend.MA        RSI     RSI[1]  \
# VGXETH           0.000000       0.125000          0.25  45.495945  44.154700
# MBOXBNB          0.222222       0.111111          0.00  52.416510  50.088508
# TRIBEBNB        -0.285714       0.232143          0.75  49.794942  57.032373
#
#             Stoch.K    Stoch.D  Stoch.K[1]  Stoch.D[1]       CCI20  ...  \
# VGXETH    58.892439  58.705462   56.230032   54.437968   53.492696  ...
# MBOXBNB   26.680727  30.215537   26.324422   36.241868   11.724232  ...
# TRIBEBNB  36.739130  36.634034   37.973988   35.234790  106.340896  ...
#
#           Pivot.M.Demark.R1      open     P.SAR  BB.lower  BB.upper  AO[2]  \
# VGXETH             0.001464  0.000871  0.000730  0.000693  0.000974    NaN
# MBOXBNB            0.028490  0.012808  0.012031  0.011565  0.015069    NaN
# TRIBEBNB           0.003221  0.001761  0.001528  0.001419  0.001742    NaN
#
#             volume    change       low      high
# VGXETH     62159.0  1.260023  0.000840  0.000888
# MBOXBNB   111922.6  4.584863  0.012609  0.013862
# TRIBEBNB  156238.0 -5.802817  0.001641  0.001776
#
# [3 rows x 91 columns]

# %%
#Extract oscillator information for all cryptos that meet the 'buy threshold'  
crypataras_picks = []
print(f'Determining which cryptos are in an optimal buying position based on trend indicators...')
print('Relative Strength Index (RSI), Moving Average Covergence and Divergence (MACD), Stachator positioning and the Awesome Oscillators')
print(f'By doing this, we can see which cryptos are currently overbought or oversold based on historical prices..')
print(f'')
def strong_performers():
    for i, j in prime_df.iterrows():
        if j['RSI'] > 45 and j['RSI'] < 90:
            print(f'{i} has passed the rsi_test, moving to moving average covergence and divergence analysis..')
            if j['MACD.macd'] > 0 and j['MACD.macd'] < 40:
                print(f'{i} has passed our moving average covergence and divergence analysis, moving to stochator analysis..')
                if j['Stoch.K'] > 35 and j['Stoch.K'] < 85:
                    if j['Stoch.D'] > 40 and j['Stoch.D'] < 85:
                        if j['Stoch.RSI.K'] > 30 and j['Stoch.RSI.K'] < 80:
                            print(f'{i} has passed our multiple stochator analysis, testing the Awesome Oscillators..')
                            if j['AO'] > 0 and j['AO'] < 55:
                                if i not in crypataras_picks:
                                    print(f'Cryptara has selected {i} ')
                                    crypataras_picks.append(i)
                                
    else:
        print(f'FAIL! dropping crypto from further consideration..')

strong_performers()
initial_count = len(crypataras_picks)
print(f'')
print('Technical Analysis test is complete.')
print('')
print('Cryptara has analyzed key technical indicators and suggest that the following crypto assets')
print('are in optimal buying positions')
print(f'Cryptara chooses: {crypataras_picks}')
# Out:
# Determining which cryptos are in an optimal buying position based on trend indicators...
# Relative Strength Index (RSI), Moving Average Covergence and Divergence (MACD), Stachator positioning and the Awesome Oscillators
# By doing this, we can see which cryptos are currently overbought or oversold based on historical prices..
#
# VGXETH has passed the rsi_test, moving to moving average covergence and divergence analysis..
# MBOXBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# TRIBEBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# VTHOBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# HARDBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# HARDBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# ETHDOWNUSDT has passed the rsi_test, moving to moving average covergence and divergence analysis..
# PHABTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# PHABTC has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# CELOUSD has passed the rsi_test, moving to moving average covergence and divergence analysis..
# CELOUSD has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# ELFETH has passed the rsi_test, moving to moving average covergence and divergence analysis..
# ELFETH has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# BUSDBRL has passed the rsi_test, moving to moving average covergence and divergence analysis..
# BUSDBRL has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# BUSDBRL has passed our multiple stochator analysis, testing the Awesome Oscillators..
# Cryptara has selected BUSDBRL
# USDTBRL has passed the rsi_test, moving to moving average covergence and divergence analysis..
# USDTBRL has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# USDTBRL has passed our multiple stochator analysis, testing the Awesome Oscillators..
# Cryptara has selected USDTBRL
# TRXXRP has passed the rsi_test, moving to moving average covergence and divergence analysis..
# TRXXRP has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# SWRVBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# SWRVBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# TRXDOWNUSDT has passed the rsi_test, moving to moving average covergence and divergence analysis..
# TRXDOWNUSDT has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# SYSBTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# SYSBTC has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# ADABTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# TROYUSDT has passed the rsi_test, moving to moving average covergence and divergence analysis..
# TROYUSDT has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# OMGBTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# OMGBTC has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# OMGBTC has passed our multiple stochator analysis, testing the Awesome Oscillators..
# Cryptara has selected OMGBTC
# TROYBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# TROYBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# CELOBTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# CELOBTC has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# PERLBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# PERLBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# BTCDOMUSDTPERP has passed the rsi_test, moving to moving average covergence and divergence analysis..
# BTCDOMUSDTPERP has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# ACMBTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# ACMBTC has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# ADAETH has passed the rsi_test, moving to moving average covergence and divergence analysis..
# OMGETH has passed the rsi_test, moving to moving average covergence and divergence analysis..
# OMGETH has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# OMGETH has passed our multiple stochator analysis, testing the Awesome Oscillators..
# Cryptara has selected OMGETH
# ELFBTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# ELFBTC has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# ADABNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# ADABNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# LPTBTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# TORNBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# TORNBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# MINABNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# MINABNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# SOLBTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# SOLBTC has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# SOLBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# SOLBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# TRXBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# TRXBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# NMRBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# NMRBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# FETBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# FETBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# UNIDOWNUSDT has passed the rsi_test, moving to moving average covergence and divergence analysis..
# UNIDOWNUSDT has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# UNIDOWNUSDT has passed our multiple stochator analysis, testing the Awesome Oscillators..
# Cryptara has selected UNIDOWNUSDT
# LPTBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# LPTBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# LTCDOWNUSDT has passed the rsi_test, moving to moving average covergence and divergence analysis..
# ASRBTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# ASRBTC has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# USDTTRY has passed the rsi_test, moving to moving average covergence and divergence analysis..
# USDTTRY has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# CELOUSDT has passed the rsi_test, moving to moving average covergence and divergence analysis..
# CELOUSDT has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# BUSDTRY has passed the rsi_test, moving to moving average covergence and divergence analysis..
# BUSDTRY has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# XLMDOWNUSDT has passed the rsi_test, moving to moving average covergence and divergence analysis..
# XLMDOWNUSDT has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# XLMDOWNUSDT has passed our multiple stochator analysis, testing the Awesome Oscillators..
# Cryptara has selected XLMDOWNUSDT
# PERLBTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# QNTBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# QNTBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# BUSDDAI has passed the rsi_test, moving to moving average covergence and divergence analysis..
# BUSDDAI has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# BUSDDAI has passed our multiple stochator analysis, testing the Awesome Oscillators..
# TROYBNB has passed the rsi_test, moving to moving average covergence and divergence analysis..
# TROYBNB has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# ELFBTC has passed the rsi_test, moving to moving average covergence and divergence analysis..
# ELFBTC has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# OMGETH has passed the rsi_test, moving to moving average covergence and divergence analysis..
# OMGETH has passed our moving average covergence and divergence analysis, moving to stochator analysis..
# OMGETH has passed our multiple stochator analysis, testing the Awesome Oscillators..
# FAIL! dropping crypto from further consideration..
#
# Technical Analysis test is complete.
#
# Cryptara has analyzed key technical indicators and suggest that the following crypto assets
# are in optimal buying positions
# Cryptara chooses: ['BUSDBRL', 'USDTBRL', 'OMGBTC', 'OMGETH', 'UNIDOWNUSDT', 'XLMDOWNUSDT']

# %%
print(f'{initial_count} tickers are in optimal buying positions..testing data population requirements..')
print(f'')
#Test if we have a minimum of five tickers for final analyses.
if len(crypataras_picks) > 5:
        crypataras_picks.remove(random.choice(crypataras_picks))
        print(f'removed ticker from list to meet maxiumum requirements')

if len(crypataras_picks) < 5:
    print('This program requires a minimum of five cryptos to run remaining analysis.')
    computer_selection_1 = subprime_df.sample().reset_index()
    ticker_random_1 = computer_selection_1.iloc[:, 0].tolist()
    string=''.join([str(item) for item in ticker_random_1])
    if string in crypataras_picks:
        pass
    else:
        crypataras_picks.append(string)
        print(f'added {string} from BUY list to meet minimum requirements')
        
if len(crypataras_picks) < 5:
    print('This program requires a minimum of five cryptos to run remaining analysis.')
    computer_selection_2 = subprime_df.sample().reset_index()
    ticker_random_2 = computer_selection_2.iloc[:, 0].tolist()
    string=''.join([str(item) for item in ticker_random_2])
    if string in crypataras_picks:
        pass
    else:
        crypataras_picks.append(string)
        print(f'added {string} from BUY list to meet minimum requirements')
        
if len(crypataras_picks) < 5:
    print('This program requires a minimum of five cryptos to run remaining analysis')
    computer_selection_3 = subprime_df.sample().reset_index()
    ticker_random_3 = computer_selection_3.iloc[:, 0].tolist()
    string=''.join([str(item) for item in ticker_random_3])
    if string in crypataras_picks:
        pass
    else:
        crypataras_picks.append(string)
        print(f'added {string} from BUY list to meet minimum requirements')
        
if len(crypataras_picks) < 5:
    print('This program requires a minimum of five cryptos to run remaining analysis')
    computer_selection_4 = subprime_df.sample().reset_index()
    ticker_random_4 = computer_selection_4.iloc[:, 0].tolist()
    string=''.join([str(item) for item in ticker_random_4])
    if string in crypataras_picks:
        pass
    else:
        crypataras_picks.append(string)
        print(f'added {string} from BUY list to meet minimum requirements')

if len(crypataras_picks) > 5:
        crypataras_picks.remove(random.choice(crypataras_picks))
        print(f'removed ticker from list to meet maxiumum requirements')
if len(crypataras_picks) > 5:
        crypataras_picks.remove(random.choice(crypataras_picks))
        print(f'removed ticker from list to meet maxiumum requirements')
if len(crypataras_picks) > 5:
        crypataras_picks.remove(random.choice(crypataras_picks))
        print(f'removed ticker from list to meet maxiumum requirements')

print(f'')
print(f'Here are the final Cryptara picks:')
print(f'')
csv_export = pd.DataFrame(crypataras_picks)
csv_export.to_csv('data_files/cryptaras_final_cryptos.csv')
crypataras_picks
# Out:
# 6 tickers are in optimal buying positions..testing data population requirements..
#
# removed ticker from list to meet maxiumum requirements
#
# Here are the final Cryptara picks:
# ['BUSDBRL', 'USDTBRL', 'OMGBTC', 'UNIDOWNUSDT', 'XLMDOWNUSDT']

# %%
from tvDatafeed import TvDatafeed,Interval
load_dotenv()
tradev_id = os.getenv("username")
tradev_secret_key = os.getenv("password")
print(f'Gathering return data on Cryptaras picks..')
logging.basicConfig(level=logging.DEBUG)
tv = TvDatafeed(tradev_id, tradev_secret_key, chromedriver_path=None)
# Out:
# DEBUG:tvDatafeed.main:auth loaded
# Gathering return data on Cryptaras picks..

# %%
print(f'Extracting most recent prices..')
final_crypto_df = pd.DataFrame()
bars= 1000
for all_picks in crypataras_picks:
    picks_df = tv.get_hist(symbol=all_picks,
                       exchange=exchange,
                       interval=Interval.in_daily,
                       n_bars=bars)
    final_crypto_df = final_crypto_df.append(picks_df)
print(f'Give me a moment while I reformat some datasets to obtain an optimal performance strategy..')
# Out:
# DEBUG:root:creating websocket connection
# Extracting most recent prices..
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDBRL...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTBRL...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:OMGBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:UNIDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:XLMDOWNUSDT...
# Give me a moment while I reformat some datasets to obtain an optimal performance strategy..

# %%
#Format dataframe.
#Step 1: extract exchange and ticker from 'symbol' column into separate columns.
final_df_cleaner = final_crypto_df
final_df_cleaner[['exchange', 'ticker']] = final_df_cleaner['symbol'].str.split(':',expand=True)
#Step 2: Extract ticker and close values, reset index
final_df_cleaner = final_df_cleaner[['ticker','close']]
final_df_cleaner = final_df_cleaner[['ticker','close']].reset_index()
#Step3: Pivot data to make ticker values the column headers
final_df_cleaner = final_df_cleaner.pivot(index='datetime',
           columns='ticker',
           values='close')
#Step4: calculate return data
print('Extracted the historical returns for Cryparas picks..')
crypto_pick_returns = final_df_cleaner.pct_change().dropna()
crypto_pick_returns.tail(5)
# Out:
# Extracted the historical returns for Cryparas picks..
# ticker                BUSDBRL    OMGBTC  UNIDOWNUSDT   USDTBRL  XLMDOWNUSDT
# datetime
# 2021-09-17 19:00:00 -0.002814  0.013356    -0.020864 -0.002813    -0.025996
# 2021-09-18 19:00:00  0.000000  0.124108     0.067435 -0.000564     0.074942
# 2021-09-19 19:00:00  0.010722  0.167074     0.338657  0.010726     0.252521
# 2021-09-20 19:00:00 -0.010609 -0.123064     0.193158 -0.009495     0.161011
# 2021-09-21 19:00:00  0.003762  0.011933    -0.242170  0.003759    -0.186922

# %%
#Step5: Calculate Cumulative Returns
print('Getting a feel for each cryptos LTD cumulative returns ..')
cumulative_daily_returns = (1 + crypto_pick_returns).cumprod() -1
cumulative_daily_returns.tail(10)
# Out:
# Getting a feel for each cryptos LTD cumulative returns ..
# ticker                BUSDBRL    OMGBTC  UNIDOWNUSDT   USDTBRL  XLMDOWNUSDT
# datetime
# 2021-09-12 19:00:00  0.023875  0.151990     0.473007  0.024261    -0.243130
# 2021-09-13 19:00:00  0.030333  0.150181     0.037762  0.029935    -0.304348
# 2021-09-14 19:00:00  0.027006  0.138721    -0.127273  0.026609    -0.353217
# 2021-09-15 19:00:00  0.035225  0.130881    -0.030769  0.034827    -0.304696
# 2021-09-16 19:00:00  0.043249  0.083836     0.139580  0.043240    -0.234000
# 2021-09-17 19:00:00  0.040313  0.098311     0.115804  0.040305    -0.253913
# 2021-09-18 19:00:00  0.040313  0.234620     0.191049  0.039718    -0.198000
# 2021-09-19 19:00:00  0.051468  0.440893     0.594406  0.050871     0.004522
# 2021-09-20 19:00:00  0.040313  0.263571     0.902378  0.040892     0.166261
# 2021-09-21 19:00:00  0.044227  0.278649     0.441678  0.044805    -0.051739

# %%
#Step5: Calculate Cumulative Returns
print('Activating Smartfolio program to determine optimal investment strategy..')
print('')
print('Logging returns to normalize dataset..')
log_returns= np.log(abs(cumulative_daily_returns))
log_returns.tail()
# Out:
# Activating Smartfolio program to determine optimal investment strategy..
#
# Logging returns to normalize dataset..
# ticker                BUSDBRL    OMGBTC  UNIDOWNUSDT   USDTBRL  XLMDOWNUSDT
# datetime
# 2021-09-17 19:00:00 -3.211079 -2.319617    -2.155854 -3.211274    -1.370763
# 2021-09-18 19:00:00 -3.211079 -1.449788    -1.655226 -3.225944    -1.619488
# 2021-09-19 19:00:00 -2.966801 -0.818954    -0.520193 -2.978469    -5.398859
# 2021-09-20 19:00:00 -3.211079 -1.333434    -0.102722 -3.196816    -1.794197
# 2021-09-21 19:00:00 -3.118420 -1.277802    -0.817173 -3.105428    -2.961541

# %%
#Calculate volatility and Initialize variables 
print(f'Running multiple scenaries to determine appropriate weights for selected cryptos')

num_of_portfolios= 5000
weight= np.zeros((num_of_portfolios,len(crypataras_picks)))
expected_return=  np.zeros(num_of_portfolios)
expected_volatility= np.zeros(num_of_portfolios)
sharpe_ratio= np.zeros(num_of_portfolios)
expected_return
mean_log_ret= log_returns.mean()
sigma = log_returns.cov()

for i in range (num_of_portfolios):
    # generate random weight vectos 
    w= np.array(np.random.random(len(crypataras_picks)))
        #sum of weights equal to 1 
    w= w/ np.sum(w)
    weight[i,:]= w
    
    # expected log return 
    expected_return[i]= np.sum(mean_log_ret*w)
    
    #expected volatility 
    expected_volatility[i]= np.sqrt(np.dot(w.T,np.dot(sigma,w)))
    
    # sharpe ratio
    sharpe_ratio[i] =  expected_return[i]/expected_volatility[i]
    
print(f'Here are the weights: ')
# Weighted portfolio that sharpe ratio
max_index = sharpe_ratio.argmax()
weight[max_index,:]
# Out:
# Running multiple scenaries to determine appropriate weights for selected cryptos
# Here are the weights:
# array([0.00832837, 0.10323588, 0.4209337 , 0.01159772, 0.45590433])

# %%
# Portfolio weights are exported to a csv that can be used for monteclaro simulation
print(f'Loading Smartfolio weights..')
print(f'')
print(f'')
portfolio_weights = np.array([weight[max_index,:]])
portfolio_weights = portfolio_weights.tolist() 
smartfolio_weights = pd.DataFrame(portfolio_weights)
total_invested=(smartfolio_weights*investment).round(2)
smartfolio_weights.to_csv('data_files/smartfolio_weights.csv')
smartfolio_weights_df = smartfolio_weights
smartfolio_weights_df.columns = ([crypataras_picks])
print(f' ............and DONE!')

print('')
print('')
print(f'At this moment in time, here is how you should allocate your {investment} investment...') 
print('')
#print(f' The optimal portfolio weight for '
print(f'With a {smartfolio_weights.iloc[0][0]:.3f} weight, Cryptara suggests that ${total_invested.iloc[0][0]} should be allocated to {crypataras_picks[0]}.')
print('')
print(f'With a {smartfolio_weights.iloc[0][1]:.3f} weight, Cryptara suggests that ${total_invested.iloc[0][1]} should be allocated to {crypataras_picks[1]}.')
print('')
print(f'With a {smartfolio_weights.iloc[0][2]:.3f} weight, Cryptara suggests that ${total_invested.iloc[0][2]} should be allocated to {crypataras_picks[2]}.')
print('')
print(f'With a {smartfolio_weights.iloc[0][3]:.3f} weight, Cryptara suggests that ${total_invested.iloc[0][3]} should be allocated to {crypataras_picks[3]}.')
print('')
print(f'With a {smartfolio_weights.iloc[0][4]:.3f} weight, Cryptara suggests that ${total_invested.iloc[0][4]} should be allocated to {crypataras_picks[4]}.')
# Out:
# Loading Smartfolio weights..
#
#
#  ............and DONE!
#
#
# At this moment in time, here is how you should allocate your 100000000.0 investment...
#
# With a 0.008 weight, Cryptara suggests that $832837.07 should be allocated to BUSDBRL.
#
# With a 0.103 weight, Cryptara suggests that $10323587.63 should be allocated to USDTBRL.
#
# With a 0.421 weight, Cryptara suggests that $42093369.85 should be allocated to OMGBTC.
#
# With a 0.012 weight, Cryptara suggests that $1159772.46 should be allocated to UNIDOWNUSDT.
#
# With a 0.456 weight, Cryptara suggests that $45590433.0 should be allocated to XLMDOWNUSDT.

# %%
import itertools
from itertools import product
from MCForecastTools import MCSimulation
# %matplotlib inline
# Out:
# DEBUG:matplotlib.pyplot:Loaded backend module://matplotlib_inline.backend_inline version unknown.

# %%
mcsims_df = pd.DataFrame()
for final_cryptos in crypataras_picks:
    mcsims = tv.get_hist(symbol=final_cryptos,
                       exchange=exchange,
                       interval=Interval.in_daily,
                       n_bars=bars)
    mcsims_df = mcsims_df.append(mcsims)

ticker1_df = mcsims_df.loc[mcsims_df.symbol==f'{exchange}' + ':' +f'{crypataras_picks[0]}']
ticker2_df = mcsims_df.loc[mcsims_df.symbol==f'{exchange}' + ':' +f'{crypataras_picks[1]}']
ticker3_df = mcsims_df.loc[mcsims_df.symbol==f'{exchange}' + ':' +f'{crypataras_picks[2]}']
ticker4_df = mcsims_df.loc[mcsims_df.symbol==f'{exchange}' + ':' +f'{crypataras_picks[3]}']
ticker5_df = mcsims_df.loc[mcsims_df.symbol==f'{exchange}' + ':' +f'{crypataras_picks[4]}']
sim_data = pd.concat([ticker1_df, ticker2_df, ticker3_df, ticker4_df, ticker5_df], axis='columns', join='inner')


print(f'Finished extracting extracting historical prices for selected cryptos')
mcsims_df.head(5)
# Out:
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDBRL...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTBRL...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:OMGBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:UNIDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:XLMDOWNUSDT...
# Finished extracting extracting historical prices for selected cryptos
#                               symbol   open   high    low  close     volume
# datetime
# 2020-11-19 18:00:00  BINANCE:BUSDBRL  5.300  5.404  5.293  5.396   89565.57
# 2020-11-20 18:00:00  BINANCE:BUSDBRL  5.396  5.406  5.362  5.378   31781.66
# 2020-11-21 18:00:00  BINANCE:BUSDBRL  5.400  5.451  5.400  5.420   46568.95
# 2020-11-22 18:00:00  BINANCE:BUSDBRL  5.427  5.484  5.399  5.462  166497.61
# 2020-11-23 18:00:00  BINANCE:BUSDBRL  5.470  5.480  5.411  5.455  168729.74

# %%
print(f'Now that we know exactly how to pool your funds, Monte Carlo should help us predict where this {investment} should go in the future...')

mdex = itertools.product(crypataras_picks, ticker1_df.columns)
columns = []
for x in mdex:
 columns.append(x)
sim_data.columns = pd.MultiIndex.from_tuples(columns)
# Out:
# Now that we know exactly how to pool your funds, Monte Carlo should help us predict where this 100000000.0 should go in the future...

# %%
print('')
print(f'Initializing Monte Carlo Simulation..')
print(f'')
MC_even_dist = MCSimulation(
    portfolio_data = sim_data, 
    weights = [smartfolio_weights.iloc[0][0], smartfolio_weights.iloc[0][1], smartfolio_weights.iloc[0][2], smartfolio_weights.iloc[0][3], smartfolio_weights.iloc[0][4]],
    num_simulation=100,
    num_trading_days = 126
)
cumula_return = MC_even_dist.calc_cumulative_return()
cumula_return.to_csv('data_files/mc_df.csv')
# Out:
# Initializing Monte Carlo Simulation..
#
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# C:\Users\jteel\anaconda3\envs\tv\lib\site-packages\numpy\lib\function_base.py:4009: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
cumula_return = MC_even_dist.calc_cumulative_return()
simulated_returns_data = {
    "mean": list(MC_even_dist.simulated_return.mean(axis=1)),
    "median": list(MC_even_dist.simulated_return.median(axis=1)),
    "min": list(MC_even_dist.simulated_return.min(axis=1)),
    "max": list(MC_even_dist.simulated_return.max(axis=1))
}
df_simulated_returns = pd.DataFrame(simulated_returns_data)
df_simulated_returns.head()
df_simulated_returns.to_csv('data_files/mc_stats.csv')
crypto_pick_returns.head()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# ticker                BUSDBRL    OMGBTC  UNIDOWNUSDT   USDTBRL  XLMDOWNUSDT
# datetime
# 2020-12-11 18:00:00  0.002740  0.023522    -0.102937  0.002935    -0.105913
# 2020-12-12 18:00:00 -0.006050  0.007071    -0.139694 -0.007023    -0.258413
# 2020-12-13 18:00:00  0.004712 -0.019310    -0.102211  0.006287     0.091016
# 2020-12-14 18:00:00 -0.002931 -0.030430     0.080339 -0.001562     0.054814
# 2020-12-15 18:00:00 -0.014308 -0.033846    -0.097534 -0.014079    -0.355214

# %%
#Extract data for visualization models. Reformat datetime stamp to be in short-date format (MONTH/DAY/YEAR) and reformat volume column from exponential format
#Entire Crypto Selections
my_crypto_portfolio = crypataras_picks
dashboard_df = pd.DataFrame()
for ticker in my_crypto_portfolio:
    data = tv.get_hist(
        symbol=ticker,
        exchange=exchange,
        interval=Interval.in_daily,n_bars=1000)
    dashboard_df = dashboard_df.append(data)

dashboard_df.index = pd.to_datetime(dashboard_df.index, errors='coerce').date

dashboard_df['volume'] = (dashboard_df['volume'].astype(float)/1000).round(4).astype(float)

dashboard_df.to_csv('data_files/daily_ohlc.csv')
# Out:
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDBRL...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTBRL...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:OMGBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:UNIDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:XLMDOWNUSDT...

# %%
#Cryto one visualization data
df_1_crypto = pd.DataFrame()
data_1 = tv.get_hist(symbol=crypataras_picks[0],exchange=exchange,interval=Interval.in_daily,n_bars=1000)
df_1_crypto = df_1_crypto.append(data_1)
df_1_crypto.index = pd.to_datetime(df_1_crypto.index, errors='coerce').date
df_1_crypto['volume'] = (df_1_crypto['volume'].astype(float)/1000).round(4).astype(float)
df_1_crypto.to_csv('data_files/ticker_1.csv')
#Cryto two visualization data
df_2_crypto = pd.DataFrame()
data_2 = tv.get_hist(symbol=crypataras_picks[1],exchange=exchange,interval=Interval.in_daily,n_bars=1000)
df_2_crypto = df_2_crypto.append(data_2)
df_2_crypto.index = pd.to_datetime(df_2_crypto.index, errors='coerce').date
df_2_crypto['volume'] = (df_2_crypto['volume'].astype(float)/1000).round(4).astype(float)
df_2_crypto.to_csv('data_files/ticker_2.csv')
#Cryto three visualization data
df_3_crypto = pd.DataFrame()
data_3 = tv.get_hist(symbol=crypataras_picks[2],exchange=exchange,interval=Interval.in_daily,n_bars=1000)
df_3_crypto = df_3_crypto.append(data_3)
df_3_crypto.index = pd.to_datetime(df_3_crypto.index, errors='coerce').date
df_3_crypto['volume'] = (df_3_crypto['volume'].astype(float)/1000).round(4).astype(float)
df_3_crypto.to_csv('data_files/ticker_3.csv')
#Cryto four visualization data
df_4_crypto = pd.DataFrame()
data_4 = tv.get_hist(symbol=crypataras_picks[3],exchange=exchange,interval=Interval.in_daily,n_bars=1000)
df_4_crypto = df_4_crypto.append(data_4)
df_4_crypto.index = pd.to_datetime(df_4_crypto.index, errors='coerce').date
df_4_crypto['volume'] = (df_4_crypto['volume'].astype(float)/1000).round(4).astype(float)
df_4_crypto.to_csv('data_files/ticker_4.csv')
#Cryto five visualization data
df_5_crypto = pd.DataFrame()
data_5 = tv.get_hist(symbol=crypataras_picks[4],exchange=exchange,interval=Interval.in_daily,n_bars=1000)
df_5_crypto = df_5_crypto.append(data_5)
df_5_crypto.index = pd.to_datetime(df_5_crypto.index, errors='coerce').date
df_5_crypto['volume'] = (df_5_crypto['volume'].astype(float)/1000).round(4).astype(float)
df_5_crypto.to_csv('data_files/ticker_5.csv')
# Out:
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:BUSDBRL...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:USDTBRL...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:OMGBTC...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:UNIDOWNUSDT...
# DEBUG:root:creating websocket connection
# DEBUG:tvDatafeed.main:getting data for BINANCE:XLMDOWNUSDT...

# %%
print(f'Cryptara has finished selecting the best cryptos and determining the optimal weights')
print(f'Please see Dashboard script for final Visualization models..')
# Out:
# Cryptara has finished selecting the best cryptos and determining the optimal weights
# Please see Dashboard script for final Visualization models..
